# %%
import os
import tqdm
import numpy as np
import csv
from moviepy.editor import AudioFileClip
from decimal import Decimal
import subprocess
from collections import Counter
from decimal import *
import sys
import keras

# %% [markdown]
# # Files description
# audio_DNN_feature.ipynb- Code to extract features for Audio DNN model. For each audio file (or face video), a feature of dimension 1582 is stored in .npy file.
# audio_LSTM_feature.ipynb- Code to extract features for Audio LSTM models. Each audio input is broken into small chunks and feature of dimension 1582 is extracted for each chunk.
# audio_DNN.ipynb- Code to train Audio_DNN model.
# audio_LSTM1.ipynb- Code to train Audio LSTM models (Fixed number of the chunks)
# audio_LSTM2.ipynb- Code to train Audio LSTM models (Fixed size of a audio chunk)

# %% [markdown]
# # 1.audio_DNN_feature

# %%
curr=os.getcwd()
print(curr)
audio_dir = os.path.join(curr, 'audio_data')  # wav 또는 mp3 파일 경로
print(audio_dir)
audio_list = os.listdir(audio_dir)  
print(audio_list)
audio_list.pop(0)
print(audio_list)
# Out:
# C:\Users\liy35\project3
# C:\Users\liy35\project3\audio_data
# ['.ipynb_checkpoints', 'drunk_female_1.wav', 'drunk_female_10.wav', 'drunk_female_11.wav', 'drunk_female_12.wav', 'drunk_female_13.wav', 'drunk_female_14.wav', 'drunk_female_15.wav', 'drunk_female_16.wav', 'drunk_female_17.wav', 'drunk_female_18.wav', 'drunk_female_19.wav', 'drunk_female_2.wav', 'drunk_female_20.wav', 'drunk_female_21.wav', 'drunk_female_22.wav', 'drunk_female_23.wav', 'drunk_female_24.wav', 'drunk_female_25.wav', 'drunk_female_26.wav', 'drunk_female_27.wav', 'drunk_female_28.wav', 'drunk_female_29.wav', 'drunk_female_3.wav', 'drunk_female_4.wav', 'drunk_female_5.wav', 'drunk_female_6.wav', 'drunk_female_7.wav', 'drunk_female_8.wav', 'drunk_female_9.wav', 'drunk_male_1.wav', 'drunk_male_10.wav', 'drunk_male_11.wav', 'drunk_male_12.wav', 'drunk_male_13.wav', 'drunk_male_14.wav', 'drunk_male_15.wav', 'drunk_male_16.wav', 'drunk_male_17.wav', 'drunk_male_18.wav', 'drunk_male_19.wav', 'drunk_male_2.wav', 'drunk_male_20.wav', 'drunk_male_21.wav', 'drunk_male_22.wav', 'drunk_male_23.wav', 'drunk_male_24.wav', 'drunk_male_25.wav', 'drunk_male_26.wav', 'drunk_male_27.wav', 'drunk_male_28.wav', 'drunk_male_29.wav', 'drunk_male_3.wav', 'drunk_male_4.wav', 'drunk_male_5.wav', 'drunk_male_6.wav', 'drunk_male_7.wav', 'drunk_male_8.wav', 'drunk_male_9.wav', 'sober_female_1.wav', 'sober_female_10.wav', 'sober_female_11.wav', 'sober_female_12.wav', 'sober_female_13.wav', 'sober_female_14.wav', 'sober_female_15.wav', 'sober_female_16.wav', 'sober_female_17.wav', 'sober_female_18.wav', 'sober_female_19.wav', 'sober_female_2.wav', 'sober_female_20.wav', 'sober_female_21.wav', 'sober_female_22.wav', 'sober_female_23.wav', 'sober_female_24.wav', 'sober_female_25.wav', 'sober_female_26.wav', 'sober_
5.wav', 'sober_female_6.wav', 'sober_female_7.wav', 'sober_female_8.wav', 'sober_female_9.wav', 'sober_male_1.wav', 'sober_male_10.wav', 'sober_male_11.wav', 'sober_male_12.wav', 'sober_male_13.wav', 'sober_male_14.wav', 'sober_male_15.wav', 'sober_male_16.wav', 'sober_male_17.wav', 'sober_male_18.wav', 'sober_male_19.wav', 'sober_male_2.wav', 'sober_male_20.wav', 'sober_male_21.wav', 'sober_male_22.wav', 'sober_male_23.wav', 'sober_male_24.wav', 'sober_male_25.wav', 'sober_male_26.wav', 'sober_male_27.wav', 'sober_male_28.wav', 'sober_male_29.wav', 'sober_male_3.wav', 'sober_male_4.wav', 'sober_male_5.wav', 'sober_male_6.wav', 'sober_male_7.wav', 'sober_male_8.wav', 'sober_male_9.wav']

# %% [markdown]
# ### openSMILE feature Extraction
# : file 경로명에 절대 공백 있으면 안됩니다!!!

# %%
for i in tqdm.tqdm(audio_list):
    input_path = os.path.join(audio_dir, i)
    output_path = os.path.join(curr, 'opensmile_feat', i[:-4] + '.csv')
    print(input_path)
    print(output_path)
    smile_extract_path = r"C:\Program Files (x86)\openSMILE\bin\SMILExtract.exe"
    config_path = r"C:\Users\liy35\opensmile\config\is09-13\IS10_paraling.conf"
    command = f'SMILExtract -C "{config_path}" -I "{input_path}" -O "{output_path}"'

    
    try:
        result = subprocess.run(command, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        print(f"Successfully processed {i}")
    except subprocess.CalledProcessError as e:
        print(f"Error processing {i}, exit code: {e.returncode}")
        print(f"Error output: {e.stderr.decode()}")
# Out:
#   0%|                                                                                          | 0/116 [00:00<?, ?it/s]
# C:\Users\liy35\project3\audio_data\drunk_female_1.wav
# C:\Users\liy35\project3\opensmile_feat\drunk_female_1.csv
#   1%|▋                                                                                 | 1/116 [00:02<05:31,  2.89s/it]
# Successfully processed drunk_female_1.wav
# C:\Users\liy35\project3\audio_data\drunk_female_10.wav
# C:\Users\liy35\project3\opensmile_feat\drunk_female_10.csv
#   2%|█▍                                                                                | 2/116 [00:05<05:33,  2.93s/it]
# Successfully processed drunk_female_10.wav
# C:\Users\liy35\project3\audio_data\drunk_female_11.wav
# C:\Users\liy35\project3\opensmile_feat\drunk_female_11.csv
#   3%|██                                                                                | 3/116 [00:09<06:24,  3.40s/it]
# Successfully processed drunk_female_11.wav
# C:\Users\liy35\project3\audio_data\drunk_female_12.wav
# C:\Users\liy35\project3\opensmile_feat\drunk_female_12.csv
#   3%|██▊                                                                               | 4/116 [00:13<06:15,  3.35s/it]
# Successfully processed drunk_female_12.wav
# C:\Users\liy35\project3\audio_data\drunk_female_13.wav
# C:\Users\liy35\project3\opensmile_feat\drunk_female_13.csv
#   4%|███▌                                                                              | 5/116 [00:16<06:14,  3.38s/it]
# Successfully processed drunk_female_13.wav
# C:\Users\liy35\project3\audio_data\drunk_female_14.wav
# C:\Users\liy35\project3\opensmile_feat\drunk_female_14.csv
#   5%|████▏                                                                             | 6/116 [00:20<06:36,  3.60s/it]
# Successfully processed sober_male_9.wav

# %% [markdown]
# ## Numpy conversion

# %%
curr=os.getcwd()
in_path = os.path.join(curr, 'opensmile_feat')
out_path = os.path.join(curr, 'opensmile')

print(in_path)
print(out_path)

in_list=os.listdir(in_path)
in_list.pop(0)
print(in_list)
print(len(in_list))
# Out:
# C:\Users\liy35\project3\opensmile_feat
# C:\Users\liy35\project3\opensmile
# ['drunk_female_01.csv', 'drunk_female_02.csv', 'drunk_female_03.csv', 'drunk_female_04.csv', 'drunk_female_05.csv', 'drunk_female_06.csv', 'drunk_female_07.csv', 'drunk_female_08.csv', 'drunk_female_09.csv', 'drunk_female_1.csv', 'drunk_female_10.csv', 'drunk_female_11.csv', 'drunk_female_12.csv', 'drunk_female_13.csv', 'drunk_female_14.csv', 'drunk_female_15.csv', 'drunk_female_16.csv', 'drunk_female_17.csv', 'drunk_female_18.csv', 'drunk_female_19.csv', 'drunk_female_2.csv', 'drunk_female_20.csv', 'drunk_female_21.csv', 'drunk_female_22.csv', 'drunk_female_23.csv', 'drunk_female_24.csv', 'drunk_female_25.csv', 'drunk_female_26.csv', 'drunk_female_27.csv', 'drunk_female_28.csv', 'drunk_female_29.csv', 'drunk_female_3.csv', 'drunk_female_4.csv', 'drunk_female_5.csv', 'drunk_female_6.csv', 'drunk_female_7.csv', 'drunk_female_8.csv', 'drunk_female_9.csv', 'drunk_male_01.csv', 'drunk_male_02.csv', 'drunk_male_03.csv', 'drunk_male_04.csv', 'drunk_male_05.csv', 'drunk_male_06.csv', 'drunk_male_07.csv', 'drunk_male_08.csv', 'drunk_male_09.csv', 'drunk_male_1.csv', 'drunk_male_10.csv', 'drunk_male_11.csv', 'drunk_male_12.csv', 'drunk_male_13.csv', 'drunk_male_14.csv', 'drunk_male_15.csv', 'drunk_male_16.csv', 'drunk_male_17.csv', 'drunk_male_18.csv', 'drunk_male_19.csv', 'drunk_male_2.csv', 'drunk_male_20.csv', 'drunk_male_21.csv', 'drunk_male_22.csv', 'drunk_male_23.csv', 'drunk_male_24.csv', 'drunk_male_25.csv', 'drunk_male_26.csv', 'drunk_male_27.csv', 'drunk_male_28.csv', 'drunk_male_29.csv', 'drunk_male_3.csv', 'drunk_male_4.csv', 'drunk_male_5.csv', 'drunk_male_6.csv', 'drunk_male_7.csv', 'drunk_male_8.csv', 'drunk_male_9.csv', 'sober_female_01.csv', 'sober_female_02.csv', 'sober_female_03.csv', 'sober_female_04.csv', 'sober_female_05.csv', 'sober_female_06.csv', 'sober_female_07.csv', 'sober_female_08.csv', 'sober_female_09.csv', 'sober_female_1.csv', 'sober_female_10.csv', 'sober_female_11.csv', 'sober_female_12.csv', 'sober_female_13.csv', 'sober_female_14.csv', 'sober_female_15.csv', 'sober_female_16.csv', 'sober_female_17.csv', 'sober_female_18.csv', 'sober_female_19.csv', 'sober_female_2.csv', 'sober_female_20.csv', 'sober_female_21.csv', 'sober_female_22.csv', 'sober_female_23.csv', 'sober_female_24.csv', 'sober_female_25.csv', 'sober_female_26.csv', 'sober_female_27.csv', 'sober_female_28.csv', 'sober_female_29.csv', 'sober_female_3.csv', 'sober_female_4.csv', 'sober_female_5.csv', 'sober_female_6.csv', 'sober_female_7.csv', 'sober_female_8.csv', 'sober_female_9.csv', 'sober_male_01.csv', 'sober_male_02.csv', 'sober_male_03.csv', 'sober_male_04.csv', 'sober_male_05.csv', 'sober_male_06.csv', 'sober_male_07.csv', 'sober_male_08.csv', 'sober_male_09.csv', 'sober_male_1.csv', 'sober_male_10.csv', 'sober_male_11.csv', 'sober_male_12.csv', 'sober_male_13.csv', 'sober_male_14.csv', 'sober_male_15.csv', 'sober_male_16.csv', 'sober_male_17.csv', 'sober_male_18.csv', 'sober_male_19.csv', 'sober_male_2.csv', 'sober_male_20.csv', 'sober_male_21.csv', 'sober_male_22.csv', 'sober_male_23.csv', 'sober_male_24.csv', 'sober_male_25.csv', 'sober_male_26.csv', 'sober_male_27.csv', 'sober_male_28.csv', 'sober_male_29.csv', 'sober_male_3.csv', 'sober_male_4.csv', 'sober_male_5.csv', 'sober_male_6.csv', 'sober_male_7.csv', 'sober_male_8.csv', 'sober_male_9.csv']
# 152

# %%
for csv_name in tqdm.tqdm(in_list):
    out_name = csv_name[:-4] + '.npy'
    feat = None
    if not os.path.isfile(os.path.join(out_path, out_name)):  # 경로 결합 수정
        with open(os.path.join(in_path, csv_name)) as csvfile:
            csv_reader = csv.reader(csvfile, delimiter=',')
            count = 1
            for row in csv_reader:
                if count == 1590:  # 데이터 위치 확인 필요
                    feat = row[1:]
                    feat = feat[:-1]
                count += 1

        if feat is not None:  # feat가 None이 아닌지 확인
            np_array = np.zeros((1582))
            try:
                for i in range(1582):
                    np_array[i] = float(feat[i])  # 변환 오류 처리
            except ValueError as e:
                print(f"Error converting value to float: {e}")
                continue  # 오류 발생 시 다음 파일로 진행

            np.save(os.path.join(out_path, out_name), np_array)
        
        np.save(os.path.join(out_path, out_name),np_array)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 152/152 [00:00<00:00, 363.62it/s]

# %%
import os

out_path = "C:\\Users\\liy35\\project3\\opensmile"  # 저장된 경로
npy_files = os.listdir(out_path)
print("Generated .npy files:", npy_files)
# Out:
# Generated .npy files: ['.ipynb_checkpoints', 'drunk_female_01.npy', 'drunk_female_02.npy', 'drunk_female_03.npy', 'drunk_female_04.npy', 'drunk_female_05.npy', 'drunk_female_06.npy', 'drunk_female_07.npy', 'drunk_female_08.npy', 'drunk_female_09.npy', 'drunk_female_1.npy', 'drunk_female_10.npy', 'drunk_female_11.npy', 'drunk_female_12.npy', 'drunk_female_13.npy', 'drunk_female_14.npy', 'drunk_female_15.npy', 'drunk_female_16.npy', 'drunk_female_17.npy', 'drunk_female_18.npy', 'drunk_female_19.npy', 'drunk_female_2.npy', 'drunk_female_20.npy', 'drunk_female_21.npy', 'drunk_female_22.npy', 'drunk_female_23.npy', 'drunk_female_24.npy', 'drunk_female_25.npy', 'drunk_female_26.npy', 'drunk_female_27.npy', 'drunk_female_28.npy', 'drunk_female_29.np
# 예제 파일 불러오기
file_path = os.path.join(out_path, "drunk_female_1.npy")  # 파일 이름 수정
if os.path.isfile(file_path):
    data = np.load(file_path)
    print("Loaded .npy data:", data)
    print("Shape of data:", data.shape)
else:
    print("File not found:", file_path)
# Out:
# Loaded .npy data: [5.361000e+03 0.000000e+00 1.897662e-01 ... 4.460303e-04 6.552184e+00
#  5.998000e+01]
# Shape of data: (1582,)

# %% [markdown]
# ## Final feature dimension for variable length audio file input

# %% [markdown]
# Each audio file is broken into 76 chunks with an overlap of 50ms. Feature Dimension -[76,1582]

# %%
open_dir=os.path.join(curr, 'open_chunks')#path to save features
print(open_dir)
# Out:
# C:\Users\liy35\project3\open_chunks

# %% [markdown]
# ##### 변수 조정 가능
# time_stamp : 오디오 클립을 나누는 개수
# overlap : 각 클립이 겹치는 시간
# error_num : 오류개수 초기화

# %%
time_stamp = Decimal(76)
over_lap = Decimal(50)
error_num = 0

for i in tqdm.tqdm(audio_list):
    if not os.path.isfile(open_dir + '/' + i[:-4] + '.npy'):
        print(f"Processing file: {i}")
        
        # Getting duration of audio file
        org_path = os.path.join(audio_dir, i)
        audioclip = AudioFileClip(org_path)
        dur = Decimal(audioclip.duration * 1000.0)
        audioclip.close()
        
        # Each chunk duration
        sample_dur = Decimal(dur + over_lap * (time_stamp - 1)) / time_stamp
        step = sample_dur - over_lap
        count = 0
        ini = Decimal(0.0)
        opensmile_array = []

        while count < 76:
            start = float(ini / 1000)
            end = float((ini + sample_dur) / 1000)
            audioclip = AudioFileClip(org_path).subclip(start, end)
            input_path = os.path.join(open_dir, f'{count}.wav')
            audioclip.write_audiofile(input_path, logger=None)
            audioclip.close()
        
            # OpenSMILE features
            csv_output_path = os.path.join(open_dir, f'{count}.csv')
            config_path = r"C:\Users\liy35\opensmile\config\is09-13\IS10_paraling.conf"
            command = f'SMILExtract -C "{config_path}" -I "{input_path}" -O "{csv_output_path}"'
            print(f"Executing command: {command}")

            result = subprocess.run(command, shell=True, capture_output=True, text=True)

            if result.returncode != 0:
                print(f"Error executing command: {command}")
                print(f"Error message: {result.stderr}")

            # Check if the CSV file was created
            if os.path.isfile(csv_output_path):
                print(f"CSV file created: {csv_output_path}")
                try:
                    with open(csv_output_path, 'r') as csvfile:
                        print("Reading CSV file...")
                        cnt = 1
                        for row in csv.reader(csvfile, delimiter=','):
                            if cnt == 1590:
                                feat = row[1:]
                                feat = feat[:-1]
                            cnt += 1                            
                    np_array = np.zeros((1582))
                    for k in range(1582):
                        np_array[k] = float(feat[k])

                    if np.count_nonzero(np_array) < 1000:
                        print("Zero values problem,", np.count_nonzero(np_array), " sample_dur", sample_dur)

                    opensmile_array.append(np_array)
                except Exception as e:
                    print(f"Error reading CSV file: {e}")

            else:
                print(f"CSV file does not exist: {csv_output_path}")

            os.remove(input_path)
            os.remove(csv_output_path)
            
            ini = ini + step
            count += 1

        np_file_name = i[:-4] + '.npy'
        
        np.save(os.path.join(open_dir, np_file_name), np.array(opensmile_array))

        # Load and verify the saved npy file
        try:
            loaded_array = np.load(os.path.join(open_dir, np_file_name))
            print("Loaded array shape:", loaded_array.shape)
            print("Loaded array contents (first 5 elements):", loaded_array[:5])
        except Exception as e:
            print(f"Error loading npy file: {e}")
# Out:
#   0%|                                                                                          | 0/116 [00:00<?, ?it/s]
# Processing file: drunk_female_1.wav
# Executing command: SMILExtract -C "C:\Users\liy35\opensmile\config\is09-13\IS10_paraling.conf" -I "C:\Users\liy35\project3\open_chunks
:\Users\liy35\opensmile\config\is09-13\IS10_paraling.conf" -I "C:\Users\liy35\project3\open_chunks\75.wav" -O "C:\Users\liy35\project3\open_chunks\75.csv"
# 100%|██████████████████████████████████████████████████████████████████████████████| 116/116 [2:05:30<00:00, 64.92s/it]
# CSV file created: C:\Users\liy35\project3\open_chunks\75.csv
# Reading CSV file...
# Loaded array shape: (76, 1582)
# Loaded array contents (first 5 elements): [[7.000000e+00 7.100000e+01 2.600759e-01 ... 5.454545e-02 6.024096e+00
#   8.300000e-01]
#  [4.700000e+01 2.000000e+00 2.602585e-01 ... 2.941176e-02 2.409639e+00
#   8.300000e-01]
#  [7.600000e+01 2.700000e+01 2.036211e-01 ... 6.818182e-02 6.024096e+00
#   8.300000e-01]
#  [0.000000e+00 2.400000e+01 1.628179e-01 ... 5.000000e-02 1.084337e+01
#   8.300000e-01]
#  [6.500000e+01 1.000000e+01 1.723675e-01 ... 1.363636e-01 6.024096e+00
#   8.300000e-01]]

# %%
time_stamp=Decimal(76)
over_lap=Decimal(50)
error_num=0
for i in tqdm.tqdm(audio_list):
    if(not os.path.isfile(open_dir+'/'+i[:-4]+'.npy')):
        
        #getting duration of audio file
        org_path = os.path.join(audio_dir, i)
        audioclip = AudioFileClip(org_path)
        dur=Decimal(audioclip.duration*1000.0)
        audioclip.close()
        
        #each chunk duration
        sample_dur=Decimal(dur + over_lap*(time_stamp-1) )/time_stamp
        step=sample_dur-over_lap
        count=0
        ini=Decimal(0.0)
    
        # features appended in a list ini<=dur-sample_dur or 
        opensmile_array=[]
    
        while(count<76):
            start=float(ini/1000)
            end=float((ini+sample_dur)/1000)
            audioclip=AudioFileClip(org_path).subclip(start,end)
            input_path = os.path.join(open_dir, f'{count}.wav')
            audioclip.write_audiofile(input_path,logger =None)
            audioclip.close()
        
            #opensmile features
            csv_output_path = os.path.join(open_dir, f'{count}.csv')
            config_path = r"C:\Users\liy35\opensmile\config\is09-13\IS10_paraling.conf"
            command = f'SMILExtract -C "{config_path}" -I "{input_path}" -O "{csv_output_path}"'
            os.system(command)
            
        #creating npy file from csv file 
            print(f"CSV output path: {csv_output_path}")
            with open(csv_output_path) as csvfile:
                csv_reader=csv.reader(csvfile,delimiter=',')
                cnt=1
                for row in csv_reader:
                    if cnt==1590:
                        feat=row[1:]
                        feat=feat[:-1]
                    cnt+=1
                np_array=np.zeros((1582))
                for k in range(1582):
                    np_array[k]=float(feat[k])
        
                if np.count_nonzero(np_array)<1000:
                    print("zeros values problem,",np.count_nonzero(np_array)," sample_dur",sample_dur)
                opensmile_array.append(np_array)
        
            os.remove(input_path)
            os.remove(csv_output_path)
            
            ini=ini+step
            count+=1
        np_file_name=i[:-4]+'.npy'
        if len(opensmile_array)!=time_stamp:
            print("time dimension ",len(opensmile_array))
            print("filename ",i[:-4])
        np.save(os.path.join(open_dir,np_file_name),np.array(opensmile_array))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 116/116 [00:00<00:00, 3053.39it/s]

# %% [markdown]
# ## audio_DNN.ipynb

# %%
LENGTH=10 #in secs
FEATURE_DIM = 1582 # opensmile feature dimension for an input chunk

# %%
# USER INPUT- features_dir
# features_dir- path to save or load vgg face features
curr=os.getcwd()
repo_path=curr.split('/code')[0]
data_path = os.path.join(repo_path, 'audio_data')
features_path = repo_path  # Folder containing all features audio and video
features_dir = os.path.join(features_path, 'opensmile')# Path to save/load opensmile features

print(curr)
print(repo_path)
print(data_path)
print(features_dir)
# Out:
# C:\Users\liy35\project3
# C:\Users\liy35\project3
# C:\Users\liy35\project3\audio_data
# C:\Users\liy35\project3\opensmile

# %% [markdown]
# ### generator data split code

# %%
import csv
'''
Input-  csv_file
Output- partition train, val test. Each partition consists of list of .npy files and dictionary of labels.
'''
def train_test_split(csv_path):
    label={'Drunk':1, 'Sober':0}
    partition={}
    train={}
    val={}
    test={}
    
    train_list=[]
    val_list=[]
    test_list=[]
    train_label={}
    val_label={}
    test_label={}
    
    with open(csv_path) as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        for row in reader:
            row[0] = row[0].strip()  # 공백 제거
            print(f"Row being processed: {row}")  # 디버깅용 출력
            filename = row[2]
            filename = filename[:-4]
            if row[0] == 'train':
                train_label[filename] = label[row[1]]
                train_list.append(filename)
            elif row[0] == 'val':
                val_label[filename] = label[row[1]]
                val_list.append(filename)
            elif row[0] == 'test':
                test_label[filename] = label[row[1]]
                test_list.append(filename)
            else:
                print("Error in label:", row[0])  # 디버깅용 출력
                return None


    train['list']=train_list
    val['list']=val_list
    test['list']=test_list
    
    train['label']=train_label
    val['label']=val_label
    test['label']=test_label
    
    partition['train']=train
    partition['val']=val
    partition['test']=test
    
    return partition

def count_classes(d):
    values=list(d.values())
    zeros=values.count(0)
    return (zeros,len(values)-zeros)

class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, labels, datapath, batch_size=32, dim=(1582,), n_classes=2, shuffle=True):
        'Initialization'        
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_IDs = list_IDs
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.on_epoch_end()
        self.path = datapath

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle:
            np.random.shuffle(self.indexes)
            
    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)
        import gc
        gc.collect()
        return X, y
    
    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, *self.dim))
        y = np.empty((self.batch_size), dtype=int)

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            # Store sample
            
            file_path = os.path.join(self.path, f"{ID}.npy")
            X[i,] = np.load(file_path)
            # Store class|||
            y[i] = self.labels[ID]

        return X, keras.utils.to_categorical(y, num_classes=self.n_classes)

# %% [markdown]
# ### Build Model

# %%
from keras.optimizers import Adam
from keras.models import Model
from keras.models import load_model
from keras.layers import Dense, Input, Dropout, LSTM, Activation,BatchNormalization
from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
import keras
from time import time
import gc
import numpy as np
keras.backend.clear_session()

# %%
def create_model(num_class,dense1_units,dense2_units,dropout,input_shape=(1582,)):
    """
        Two layer DNN
    """
    X=Input(shape=input_shape)
    norm=BatchNormalization()(X)
    layer1=Dense(dense1_units, activation='relu')(norm)
    drop=Dropout(rate=dropout)(layer1)
    layer2=Dense(dense2_units, activation='relu')(drop)
    drop=Dropout(rate=dropout)(layer2)
    prob=Dense(num_class, activation='sigmoid')(layer2)
    return Model(inputs = X, outputs = prob)

def basic_model(num_class,input_shape=(1582,)):
    """
        Single layer DNN
    """
    X=Input(shape=input_shape)
    prob=Dense(num_class, activation='sigmoid')(X)
    return Model(inputs = X, outputs = prob)

# %%
dense1=256
dense2=128
#dense3=128
dropout=.2
hp=2
class_num=2
model=create_model(class_num,dense1,dense2,dropout,input_shape=(FEATURE_DIM,))
#USER INPUT, path to save/ load model
model_path=repo_path+'/saved_models/audio_open/'+str(LENGTH)+'/hp'+str(hp)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1582)]            0
#
#  batch_normalization (Batch  (None, 1582)              6328
#  Normalization)
#
#  dense (Dense)               (None, 256)               405248
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 444730 (1.70 MB)
# Trainable params: 441566 (1.68 MB)
# Non-trainable params: 3164 (12.36 KB)
# _________________________________________________________________

# %%
def load_keras_model(path):
    if os.path.isfile(path):
        return load_model(path)
#Loading data filenames split
#USER INPUT

print(repo_path)
partition=train_test_split(repo_path+'\\split.csv')# or enter path to the split.csv in the parent directory
print(partition['train'])
print("Number of training examples ")
print(len(partition['train']['list']))
print("Number of validation examples ")
print(len(partition['val']['list']))

params = {'datapath':features_dir ,
          'dim': (FEATURE_DIM,),
          'batch_size': 12,#!!!!데이터 많으면 64로 업그레이드
          'n_classes': 2,
          'shuffle': True}
    
#weights for imbalance classes
count=count_classes(partition['train']['label'])
print("Class instances in training class.\n Sober:",count[0]," Drunk:",count[1])
weight_0=float(count[0]+count[1])/float(count[0])
weight_1=float(count[0]+count[1])/float(count[1])
class_weight={0:weight_0, 1:weight_1}

#instances in val set
count=count_classes(partition['val']['label'])
print("Class instances in val class.\n Sober:",count[0]," Drunk:",count[1])

#instances in test set
count=count_classes(partition['test']['label'])
print("Class instances in test class.\n Sober:",count[0]," Drunk:",count[1])
# Out:
# C:\Users\liy35\project3
# Row being processed: ['test', 'Drunk', 'drunk_female_1.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_2.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_3.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_4.wav']
# Row being processed: ['val', 'Drunk', 'drunk_female_5.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_6.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_7.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_8.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_9.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_10.wav']
# Row being processed: ['val', 'Drunk', 'drunk_female_11.wav']
# Row being processed: ['test', 'Drunk', 'drunk_female_12.wav']
# Row being processed: ['val', 'Drunk', 'drunk_female_13.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_14.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_15.wav']
# Row being processed: ['test', 'Drunk', 'drunk_female_16.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_17.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_18.wav']
# Row being processed: ['val', 'Drunk', 'drunk_female_19.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_20.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_21.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_22.wav']
# Row being processed: ['test', 'Drunk', 'drunk_female_23.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_24.wav']
# Row being processed: ['val', 'Drunk', 'drunk_female_25.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_26.wav']
# Row being processed: ['val', 'Drunk', 'drunk_female_27.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_28.wav']
# Row being processed: ['train', 'Drunk', 'drunk_female_29.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_1.wav']
# Row being processed: ['test', 'Drunk', 'drunk_male_2.wav']
# Row being processed: ['test', 'Drunk', 'drunk_male_3.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_4.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_5.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_6.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_7.wav']
# Row being processed: ['val', 'Drunk', 'drunk_male_8.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_9.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_10.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_11.wav']
# Row being processed: ['val', 'Drunk', 'drunk_male_12.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_13.wav']
# Row being processed: ['val', 'Drunk', 'drunk_male_14.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_15.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_16.wav']
# Row being processed: ['val', 'Drunk', 'drunk_male_17.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_18.wav']
# Row being processed: ['val', 'Drunk', 'drunk_male_19.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_20.wav']
# Row being processed: ['val', 'Drunk', 'drunk_male_21.wav']
# Row being processed: ['val', 'Drunk', 'drunk_male_22.wav']
# Row being processed: ['val', 'Drunk', 'drunk_male_23.wav']
# Row being processed: ['val', 'Drunk', 'drunk_male_24.wav']
# Row being processed: ['val', 'Drunk', 'drunk_male_25.wav']
# Row being processed: ['val', 'Drunk', 'drunk_male_26.wav']
# Row being processed: ['test', 'Drunk', 'drunk_male_27.wav']
# Row being processed: ['test', 'Drunk', 'drunk_male_28.wav']
# Row being processed: ['train', 'Drunk', 'drunk_male_29.wav']
# Row being processed: ['train', 'Sober', 'sober_female_1.wav']
# Row being processed: ['train', 'Sober', 'sober_female_2.wav']
# Row being processed: ['train', 'Sober', 'sober_female_3.wav']
# Row being processed: ['train', 'Sober', 'sober_female_4.wav']
# Row being processed: ['val', 'Sober', 'sober_female_5.wav']
# Row being processed: ['train', 'Sober', 'sober_female_6.wav']
# Row being processed: ['train', 'Sober', 'sober_female_7.wav']
# Row being processed: ['train', 'Sober', 'sober_female_8.wav']
# Row being processed: ['train', 'Sober', 'sober_female_9.wav']
# Row being processed: ['val', 'Sober', 'sober_female_10.wav']
# Row being processed: ['val', 'Sober', 'sober_female_11.wav']
# Row being processed: ['train', 'Sober', 'sober_female_12.wav']
# Row being processed: ['test', 'Sober', 'sober_female_13.wav']
# Row being processed: ['train', 'Sober', 'sober_female_14.wav']
# Row being processed: ['train', 'Sober', 'sober_female_15.wav']
# Row being processed: ['train', 'Sober', 'sober_female_16.wav']
# Row being processed: ['train', 'Sober', 'sober_female_17.wav']
# Row being processed: ['train', 'Sober', 'sober_female_18.wav']
# Row being processed: ['train', 'Sober', 'sober_female_19.wav']
# Row being processed: ['train', 'Sober', 'sober_female_20.wav']
# Row being processed: ['train', 'Sober', 'sober_female_21.wav']
# Row being processed: ['train', 'Sober', 'sober_female_22.wav']
# Row being processed: ['val', 'Sober', 'sober_female_23.wav']
# Row being processed: ['train', 'Sober', 'sober_female_24.wav']
# Row being processed: ['train', 'Sober', 'sober_female_25.wav']
# Row being processed: ['val', 'Sober', 'sober_female_26.wav']
# Row being processed: ['val', 'Sober', 'sober_female_27.wav']
# Row being processed: ['val', 'Sober', 'sober_female_28.wav']
# Row being processed: ['train', 'Sober', 'sober_female_29.wav']
# Row being processed: ['train', 'Sober', 'sober_male_1.wav']
# Row being processed: ['test', 'Sober', 'sober_male_2.wav']
# Row being processed: ['train', 'Sober', 'sober_male_3.wav']
# Row being processed: ['train', 'Sober', 'sober_male_4.wav']
# Row being processed: ['train', 'Sober', 'sober_male_5.wav']
# Row being processed: ['train', 'Sober', 'sober_male_6.wav']
# Row being processed: ['val', 'Sober', 'sober_male_7.wav']
# Row being processed: ['test', 'Sober', 'sober_male_8.wav']
# Row being processed: ['train', 'Sober', 'sober_male_9.wav']
# Row being processed: ['train', 'Sober', 'sober_male_10.wav']
# Row being processed: ['train', 'Sober', 'sober_male_11.wav']
# Row being processed: ['train', 'Sober', 'sober_male_12.wav']
# Row being processed: ['train', 'Sober', 'sober_male_13.wav']
# Row being processed: ['test', 'Sober', 'sober_male_14.wav']
# Row being processed: ['train', 'Sober', 'sober_male_15.wav']
# Row being processed: ['train', 'Sober', 'sober_male_16.wav']
# Row being processed: ['train', 'Sober', 'sober_male_17.wav']
# Row being processed: ['train', 'Sober', 'sober_male_18.wav']
# Row being processed: ['train', 'Sober', 'sober_male_19.wav']
# Row being processed: ['train', 'Sober', 'sober_male_20.wav']
# Row being processed: ['train', 'Sober', 'sober_male_21.wav']
# Row being processed: ['train', 'Sober', 'sober_male_22.wav']
# Row being processed: ['val', 'Sober', 'sober_male_23.wav']
# Row being processed: ['val', 'Sober', 'sober_male_24.wav']
# Row being processed: ['train', 'Sober', 'sober_male_25.wav']
# Row being processed: ['train', 'Sober', 'sober_male_26.wav']
# Row being processed: ['train', 'Sober', 'sober_male_27.wav']
# Row being processed: ['val', 'Sober', 'sober_male_28.wav']
# Row being processed: ['train', 'Sober', 'sober_male_29.wav']
# {'list': ['drunk_female_2', 'drunk_female_3', 'drunk_female_4', 'drunk_female_6', 'drunk_female_7', 'drunk_female_8', 'drunk_female_9', 'drunk_female_10', 'drunk_female_14', 'drunk_female_15', 'drunk_female_17', 'drunk_female_18', 'drunk_female_20', 'drunk_female_21', 'drunk_female_22', 'drunk_female_24', 'drunk_female_26', 'drunk_female_28', 'drunk_female_29', 'drunk_male_1', 'drunk_male_4', 'drunk_male_5', 'drunk_male_6', 'drunk_male_7', 'drunk_male_9', 'drunk_male_10', 'drunk_male_11', 'drunk_male_13', 'drunk_male_15', 'drunk_male_16', 'drunk_male_18', 'drunk_male_20', 'drunk_male_29', 'sober_female_1', 'sober_female_2', 'sober_female_3', 'sober_female_4', 'sober_female_6', 'sober_female_7', 'sober_female_8', 'sober_female_9', 'sober_female_12', 'sober_female_14', 'sober_female_15', 'sober_female_16', 'sober_female_17', 'sober_female_18', 'sober_female_19', 'sober_female_20', 'sober_female_21', 'sober_female_22', 'sober_female_24', 'sober_female_25', 'sober_female_29', 'sober_male_1', 'sober_male_3', 'sober_male_4', 'sober_male_5', 'sober_male_6', 'sober_male_9', 'sober_male_10', 'sober_male_11', 'sober_male_12', 'sober_male_13', 'sober_male_15', 'sober_male_16', 'sober_male_17', 'sober_male_18', 'sober_male_19', 'sober_male_20', 'sober_male_21', 'sober_male_22', 'sober_male_25', 'sober_male_26', 'sober_male_27', 'sober_male_29'], 'label': {'drunk_female_2': 1, 'drunk_female_3': 1, 'drunk_female_4': 1, 'drunk_female_6': 1, 'drunk_female_7': 1, 'drunk_female_8': 1, 'drunk_female_9': 1, 'drunk_female_10': 1, 'drunk_female_14': 1, 'drunk_female_15': 1, 'drunk_female_17': 1, 'drunk_female_18': 1, 'drunk_female_20': 1, 'drunk_female_21': 1, 'drunk_female_22': 1, 'drunk_female_24': 1, 'drunk_female_26': 1, 'drunk_female_28': 1, 'drunk_female_29': 1, 'drunk_male_1': 1, 'drunk_male_4': 1, 'drunk_male_5': 1, 'drunk_male_6': 1, 'drunk_male_7': 1, 'drunk_male_9': 1, 'drunk_male_10': 1, 'drunk_male_11': 1, 'drunk_male_13': 1, 'drunk_male_15': 1, 'drunk_male_16': 1, 'drunk_male_18': 1, 'drunk_male_20': 1, 'drunk_male_29': 1, 'sober_female_1': 0, 'sober_female_2': 0, 'sober_female_3': 0, 'sober_female_4': 0, 'sober_female_6': 0, 'sober_female_7': 0, 'sober_female_8': 0, 'sober_female_9': 0, 'sober_female_12': 0, 'sober_female_14': 0, 'sober_female_15': 0, 'sober_female_16': 0, 'sober_female_17': 0, 'sober_female_18': 0, 'sober_female_19': 0, 'sober_female_20': 0, 'sober_female_21': 0, 'sober_female_22': 0, 'sober_female_24': 0, 'sober_female_25': 0, 'sober_female_29': 0, 'sober_male_1': 0, 'sober_male_3': 0, 'sober_male_4': 0, 'sober_male_5': 0, 'sober_male_6': 0, 'sober_male_9': 0, 'sober_male_10': 0, 'sober_male_11': 0, 'sober_male_12': 0, 'sober_male_13': 0, 'sober_male_15': 0, 'sober_male_16': 0, 'sober_male_17': 0, 'sober_male_18': 0, 'sober_male_19': 0, 'sober_male_20': 0, 'sober_male_21': 0, 'sober_male_22': 0, 'sober_male_25': 0, 'sober_male_26': 0, 'sober_male_27': 0, 'sober_male_29': 0}}
# Number of training examples
# 76
# Number of validation examples
# 28
# Class instances in training class.
#  Sober: 43  Drunk: 33
# Class instances in val class.
#  Sober: 11  Drunk: 17
# Class instances in test class.
#  Sober: 4  Drunk: 8

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=["accuracy"])

#saving best model
checkpoint = ModelCheckpoint(model_path+'/model-{epoch:03d}-{val_accuracy:4f}.h5', verbose=1, monitor='val_accuracy',save_best_only=False, mode='max',period=5,save_freq='epoch')

#tensorboard
tensorboard = TensorBoard(log_dir=model_path+"/log/{}".format(time()))

print(partition['train']['label'])

train_generator=DataGenerator(partition['train']['list'],partition['train']['label'], **params)
val_generator=DataGenerator(partition['val']['list'],partition['val']['label'], **params)
print("generator created")

model.fit(x=train_generator,
          epochs=10,
          validation_data=val_generator,
          use_multiprocessing=False,
          workers=6,
          callbacks=[checkpoint, tensorboard],
          class_weight=class_weight)

## !!! 추후 epoch도 늘리기
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# {'drunk_female_2': 1, 'drunk_female_3': 1, 'drunk_female_4': 1, 'drunk_female_6': 1, 'drunk_female_7': 1, 'drunk_female_8': 1, 'drunk_female_9': 1, 'drunk_female_10': 1, 'drunk_female_14': 1, 'drunk_female_15': 1, 'drunk_female_17': 1, 'drunk_female_18': 1, 'drunk_female_20': 1, 'drunk_female_21': 1, 'drunk_female_22': 1, 'drunk_female_24': 1, 'drunk_female_26': 1, 'drunk_female_28': 1, 'drunk_female_29': 1, 'drunk_male_1': 1, 'drunk_male_4': 1, 'drunk_male_5': 1, 'drunk_male_6': 1, 'drunk_male_7': 1, 'drunk_male_9': 1, 'drunk_male_10': 1, 'drunk_male_11': 1, 'drunk_male_13': 1, 'drunk_male_15': 1, 'drunk_male_16': 1, 'drunk_male_18': 1, 'drunk_male_20': 1, 'drunk_male_29': 1, 'sober_female_1': 0, 'sober_female_2': 0, 'sober_female_3': 0, 'sober_female_4': 0, 'sober_female_6': 0, 'sober_female_7': 0, 'sober_female_8': 0, 'sober_female_9': 0, 'sober_female_12': 0, 'sober_female_14': 0, 'sober_female_15': 0, 'sober_female_16': 0, 'sober_female_17': 0, 'sober_female_18': 0, 'sober_female_19': 0, 'sober_female_20': 0, 'sober_female_21': 0, 'sober_female_22': 0, 'sober_female_24': 0, 'sober_female_25': 0, 'sober_female_29': 0, 'sober_male_1': 0, 'sober_male_3': 0, 'sober_male_4': 0, 'sober_male_5': 0, 'sober_male_6': 0, 'sober_male_9': 0, 'sober_male_10': 0, 'sober_male_11': 0, 'sober_male_12': 0, 'sober_male_13': 0, 'sober_male_15': 0, 'sober_male_16': 0, 'sober_male_17': 0, 'sober_male_18': 0, 'sober_male_19': 0, 'sober_male_20': 0, 'sober_male_21': 0, 'sober_male_22': 0, 'sober_male_25': 0, 'sober_male_26': 0, 'sober_male_27': 0, 'sober_male_29': 0}
# generator created
# Epoch 1/10
# 6/6 [==============================] - 13s 2s/step - loss: 0.0587 - accuracy: 0.9861 - val_loss: 1.5869 - val_accuracy: 0.6667
# Epoch 2/10
# 6/6 [==============================] - 9s 1s/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 2.0838 - val_accuracy: 0.7083
# Epoch 3/10
# 6/6 [==============================] - 9s 2s/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 2.4410 - val_accuracy: 0.6667
# Epoch 4/10
# 6/6 [==============================] - 9s 1s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.9726 - val_accuracy: 0.6250
# Epoch 5/10
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0183 - accuracy: 1.0000
# Epoch 5: saving model to C:\Users\liy35\project3/saved_models/audio_open/10/hp2\model-005-0.666667.h5
# 6/6 [==============================] - 9s 2s/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 2.8247 - val_accuracy: 0.6667
# Epoch 6/10
# 6/6 [==============================] - 9s 1s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 2.6490 - val_accuracy: 0.6250
# Epoch 7/10
# 6/6 [==============================] - 9s 1s/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 2.4525 - val_accuracy: 0.7083
# Epoch 8/10
# 6/6 [==============================] - 8s 1s/step - loss: 1.9744e-04 - accuracy: 1.0000 - val_loss: 1.0815 - val_accuracy: 0.7500
# Epoch 9/10
# 6/6 [==============================] - 8s 1s/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 1.5193 - val_accuracy: 0.7083
# Epoch 10/10
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000
# Epoch 10: saving model to C:\Users\liy35\project3/saved_models/audio_open/10/hp2\model-010-0.583333.h5
# 6/6 [==============================] - 9s 1s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 2.5335 - val_accuracy: 0.5833

# %% [markdown]
# ## 위의 모델은 DNN 모델임

# %%
import numpy as np

# Test 데이터 생성
test_generator = DataGenerator(partition['test']['list'], partition['test']['label'], **params)

# 모델을 사용해 예측
predictions = model.predict(test_generator, use_multiprocessing=False, workers=6)

# 예측된 값 출력
#print("Predictions:", predictions)

# 테스트 레이블 가져오기
true_labels = [partition['test']['label'][ID] for ID in partition['test']['list']]

# 확률 높은 걸로
print(predictions)
classified_predictions = np.argmax(predictions, axis=1)

# 예측된 값과 실제 값 비교
for i, (pred, classified_pred, true_label) in enumerate(zip(predictions, classified_predictions, true_labels)):
    print(f"Sample {i}: Raw Predicted={pred}, Classified Predicted={classified_pred}, True={true_label}")
# Out:
# 1/1 [==============================] - 0s 422ms/step
# [[4.3497123e-05 9.9983609e-01]
#  [4.7491067e-06 9.9999911e-01]
#  [8.9860742e-07 9.9999988e-01]
#  [3.0145600e-02 9.1572118e-01]
#  [9.9991411e-01 2.4717047e-03]
#  [9.9999636e-01 6.0228886e-06]
#  [9.2516005e-01 1.6220871e-01]
#  [6.0501719e-08 1.0000000e+00]
#  [1.0000000e+00 1.1494085e-12]
#  [3.6052330e-05 9.9994344e-01]
#  [2.4031478e-04 9.9995577e-01]
#  [9.9437338e-01 6.8101687e-03]]
# Sample 0: Raw Predicted=[4.3497123e-05 9.9983609e-01], Classified Predicted=1, True=1
# Sample 1: Raw Predicted=[4.7491067e-06 9.9999911e-01], Classified Predicted=1, True=1
# Sample 2: Raw Predicted=[8.986074e-07 9.999999e-01], Classified Predicted=1, True=1
# Sample 3: Raw Predicted=[0.0301456 0.9157212], Classified Predicted=1, True=1
# Sample 4: Raw Predicted=[0.9999141 0.0024717], Classified Predicted=0, True=1
# Sample 5: Raw Predicted=[9.9999636e-01 6.0228886e-06], Classified Predicted=0, True=1
# Sample 6: Raw Predicted=[0.92516005 0.1622087 ], Classified Predicted=0, True=1
# Sample 7: Raw Predicted=[6.050172e-08 1.000000e+00], Classified Predicted=1, True=1
# Sample 8: Raw Predicted=[1.0000000e+00 1.1494085e-12], Classified Predicted=0, True=0
# Sample 9: Raw Predicted=[3.6052330e-05 9.9994344e-01], Classified Predicted=1, True=0
# Sample 10: Raw Predicted=[2.4031478e-04 9.9995577e-01], Classified Predicted=1, True=0
# Sample 11: Raw Predicted=[0.9943734  0.00681017], Classified Predicted=0, True=0

# %%
# 길이 확인
print(f"Length of true_labels: {len(true_labels)}")
print(f"Length of classified_predictions: {len(classified_predictions)}")

# 예: 길이가 다른 경우, 수정
# 필요에 따라 true_labels 또는 classified_predictions를 수정하세요
if len(true_labels) != len(classified_predictions):
    min_length = min(len(true_labels), len(classified_predictions))
    true_labels = true_labels[:min_length]
    classified_predictions = classified_predictions[:min_length]
# Out:
# Length of true_labels: 12
# Length of classified_predictions: 12

# %%
from sklearn.metrics import accuracy_score, precision_score, f1_score, roc_auc_score, matthews_corrcoef, confusion_matrix

# 정확도 계산
accuracy = accuracy_score(true_labels, classified_predictions)

# 정밀도 계산
precision = precision_score(true_labels, classified_predictions)

# F1 점수 계산
f1 = f1_score(true_labels, classified_predictions)

# MCC 계산
mcc = matthews_corrcoef(true_labels, classified_predictions)

# 혼동 행렬 출력 (추가)
conf_matrix = confusion_matrix(true_labels, classified_predictions)

# 결과 출력
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"MCC: {mcc:.4f}")
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Accuracy: 0.5833
# Precision: 0.7143
# F1 Score: 0.6667
# MCC: 0.1195
# Confusion Matrix:
# [[2 2]
#  [3 5]]
